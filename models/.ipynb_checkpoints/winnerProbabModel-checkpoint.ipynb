# %%
import fastf1
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
session = fastf1.get_session(2026, 'Australia', 'Q')
session.load()

results = session.results
print(results)
# Out:
# core           INFO 	Loading data for Australian Grand Prix - Qualifying [v3.8.1]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 18
# core        WARNING 	No lap data for driver 55
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 18)
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 55)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 22 drivers: ['63', '12', '6', '16', '81', '1', '44', '30', '41', '5', '27', '87', '31', '10', '23', '43', '14', '11', '77', '18', '3', '55']
#    DriverNumber BroadcastName Abbreviation        DriverId         TeamName  \
# 63           63     G RUSSELL          RUS         russell         Mercedes
# 12           12   K ANTONELLI          ANT       antonelli         Mercedes
# 6             6      I HADJAR          HAD          hadjar  Red Bull Racing
# 16           16     C LECLERC          LEC         leclerc          Ferrari
# 81           81     O PIASTRI          PIA         piastri          McLaren
# 1             1      L NORRIS          NOR          norris          McLaren
# 44           44    L HAMILTON          HAM        hamilton          Ferrari
# 30           30      L LAWSON          LAW          lawson     Racing Bulls
# 41           41    A LINDBLAD          LIN  arvid_lindblad     Racing Bulls
# 5             5   G BORTOLETO          BOR       bortoleto             Audi
# 27           27  N HULKENBERG          HUL      hulkenberg             Audi
# 87           87     O BEARMAN          BEA         bearman     Haas F1 Team
# 31           31        E OCON          OCO            ocon     Haas F1 Team
# 10           10       P GASLY          GAS           gasly           Alpine
# 23           23       A ALBON          ALB           albon         Williams
# 43           43   F COLAPINTO          COL       colapinto           Alpine
# 14           14      F ALONSO          ALO          alonso     Aston Martin
# 11           11       S PEREZ          PER           perez         Cadillac
# 77           77      V BOTTAS          BOT          bottas         Cadillac
# 18           18      L STROLL          STR             nan     Aston Martin
# 3             3  M VERSTAPPEN          VER             nan  Red Bull Racing
# 55           55       C SAINZ          SAI             nan         Williams
#
#    TeamColor        TeamId  FirstName    LastName           FullName  ...  \
# 63    00D7B6      mercedes     George     Russell     George Russell  ...
# 12    00D7B6      mercedes       Kimi   Antonelli     Kimi Antonelli  ...
# 6     4781D7      red_bull      Isack      Hadjar       Isack Hadjar  ...
# 16    ED1131       ferrari    Charles     Leclerc    Charles Leclerc  ...
# 81    F47600       mclaren      Oscar     Piastri      Oscar Piastri  ...
# 1     F47600       mclaren      Lando      Norris       Lando Norris  ...
# 44    ED1131       ferrari      Lewis    Hamilton     Lewis Hamilton  ...
# 30    6C98FF            rb       Liam      Lawson        Liam Lawson  ...
# 41    6C98FF            rb      Arvid    Lindblad     Arvid Lindblad  ...
# 5     F50537          audi    Gabriel   Bortoleto  Gabriel Bortoleto  ...
# 27    F50537          audi       Nico  Hulkenberg    Nico Hulkenberg  ...
# 87    9C9FA2          haas     Oliver     Bearman     Oliver Bearman  ...
# 31    9C9FA2          haas    Esteban        Ocon       Esteban Ocon  ...
# 10    00A1E8        alpine     Pierre       Gasly       Pierre Gasly  ...
# 23    1868DB      williams  Alexander       Albon    Alexander Albon  ...
# 43    00A1E8        alpine     Franco   Colapinto   Franco Colapinto  ...
# 14    229971  aston_martin   Fernando      Alonso    Fernando Alonso  ...
# 11    909090      cadillac     Sergio       Perez       Sergio Perez  ...
# 77    909090      cadillac   Valtteri      Bottas    Valtteri Bottas  ...
# 18    229971           nan      Lance      Stroll       Lance Stroll  ...
# 3     4781D7           nan        Max  Verstappen     Max Verstappen  ...
# 55    1868DB           nan     Carlos       Sainz       Carlos Sainz  ...
#
#    Position ClassifiedPosition  GridPosition                     Q1  \
# 63      1.0                              NaN 0 days 00:01:19.507000
# 12      2.0                              NaN 0 days 00:01:20.120000
# 6       3.0                              NaN 0 days 00:01:20.023000
# 16      4.0                              NaN 0 days 00:01:20.226000
# 81      5.0                              NaN 0 days 00:01:19.664000
# 1       6.0                              NaN 0 days 00:01:20.010000
# 44      7.0                              NaN 0 days 00:01:19.811000
# 30      8.0                              NaN 0 days 00:01:20.491000
# 41      9.0                              NaN 0 days 00:01:20.409000
# 5      10.0                              NaN 0 days 00:01:20.495000
# 27     11.0                              NaN 0 days 00:01:21.024000
# 87     12.0                              NaN 0 days 00:01:21.247000
# 31     13.0                              NaN 0 days 00:01:20.759000
# 10     14.0                              NaN 0 days 00:01:21.138000
# 23     15.0                              NaN 0 days 00:01:21.051000
# 43     16.0                              NaN 0 days 00:01:21.200000
# 14     17.0                              NaN 0 days 00:01:21.969000
# 11     18.0                              NaN 0 days 00:01:22.605000
# 77     19.0                              NaN 0 days 00:01:23.244000
# 18      NaN                              NaN                    NaT
# 3       NaN                              NaN                    NaT
# 55      NaN                              NaN                    NaT
#
#                        Q2                     Q3 Time Status Points Laps
# 63 0 days 00:01:18.934000 0 days 00:01:18.518000  NaT           NaN  NaN
# 12 0 days 00:01:19.435000 0 days 00:01:18.811000  NaT           NaN  NaN
# 6  0 days 00:01:19.653000 0 days 00:01:19.303000  NaT           NaN  NaN
# 16 0 days 00:01:19.357000 0 days 00:01:19.327000  NaT           NaN  NaN
# 81 0 days 00:01:19.525000 0 days 00:01:19.380000  NaT           NaN  NaN
# 1  0 days 00:01:19.882000 0 days 00:01:19.475000  NaT           NaN  NaN
# 44 0 days 00:01:19.921000 0 days 00:01:19.478000  NaT           NaN  NaN
# 30 0 days 00:01:20.144000 0 days 00:01:19.994000  NaT           NaN  NaN
# 41 0 days 00:01:19.971000 0 days 00:01:21.247000  NaT           NaN  NaN
# 5  0 days 00:01:20.221000                    NaT  NaT           NaN  NaN
# 27 0 days 00:01:20.303000                    NaT  NaT           NaN  NaN
# 87 0 days 00:01:20.311000                    NaT  NaT           NaN  NaN
# 31 0 days 00:01:20.491000                    NaT  NaT           NaN  NaN
# 10 0 days 00:01:20.501000                    NaT  NaT           NaN  NaN
# 23 0 days 00:01:20.941000                    NaT  NaT           NaN  NaN
# 43 0 days 00:01:21.270000                    NaT  NaT           NaN  NaN
# 14                    NaT                    NaT  NaT           NaN  NaN
# 11                    NaT                    NaT  NaT           NaN  NaN
# 77                    NaT                    NaT  NaT           NaN  NaN
# 18                    NaT                    NaT  NaT           NaN  NaN
# 3                     NaT                    NaT  NaT           NaN  NaN
# 55                    NaT                    NaT  NaT           NaN  NaN
#
# [22 rows x 22 columns]

# %%
quali = session.results[['DriverNumber','Position','Abbreviation', 'Q3']]
print(quali)
# Out:
#    DriverNumber  Position Abbreviation                     Q3
# 63           63       1.0          RUS 0 days 00:01:18.518000
# 12           12       2.0          ANT 0 days 00:01:18.811000
# 6             6       3.0          HAD 0 days 00:01:19.303000
# 16           16       4.0          LEC 0 days 00:01:19.327000
# 81           81       5.0          PIA 0 days 00:01:19.380000
# 1             1       6.0          NOR 0 days 00:01:19.475000
# 44           44       7.0          HAM 0 days 00:01:19.478000
# 30           30       8.0          LAW 0 days 00:01:19.994000
# 41           41       9.0          LIN 0 days 00:01:21.247000
# 5             5      10.0          BOR                    NaT
# 27           27      11.0          HUL                    NaT
# 87           87      12.0          BEA                    NaT
# 31           31      13.0          OCO                    NaT
# 10           10      14.0          GAS                    NaT
# 23           23      15.0          ALB                    NaT
# 43           43      16.0          COL                    NaT
# 14           14      17.0          ALO                    NaT
# 11           11      18.0          PER                    NaT
# 77           77      19.0          BOT                    NaT
# 18           18       NaN          STR                    NaT
# 3             3       NaN          VER                    NaT
# 55           55       NaN          SAI                    NaT

# %%
race = fastf1.get_session(2026, 'Australia', 'R')
race.load()

race_results = race.results
race_df = race_results[['DriverNumber', 'Position', 'Abbreviation']]
print(race_df)
# Out:
# core           INFO 	Loading data for Australian Grand Prix - Race [v3.8.1]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 81
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 81)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 22 drivers: ['63', '12', '16', '44', '1', '3', '87', '41', '5', '10', '31', '23', '30', '43', '55', '11', '18', '14', '77', '6', '81', '27']
#    DriverNumber  Position Abbreviation
# 63           63       1.0          RUS
# 12           12       2.0          ANT
# 16           16       3.0          LEC
# 44           44       4.0          HAM
# 1             1       5.0          NOR
# 3             3       6.0          VER
# 87           87       7.0          BEA
# 41           41       8.0          LIN
# 5             5       9.0          BOR
# 10           10      10.0          GAS
# 31           31      11.0          OCO
# 23           23      12.0          ALB
# 30           30      13.0          LAW
# 43           43      14.0          COL
# 55           55      15.0          SAI
# 11           11      16.0          PER
# 18           18      17.0          STR
# 14           14      18.0          ALO
# 77           77      19.0          BOT
# 6             6      20.0          HAD
# 81           81      21.0          PIA
# 27           27      22.0          HUL

# %%
merged = pd.merge(quali, race_df, on='DriverNumber')
print(merged)
# Out:
#    DriverNumber  Position_x Abbreviation_x                     Q3  Position_y  \
# 0            63         1.0            RUS 0 days 00:01:18.518000         1.0
# 1            12         2.0            ANT 0 days 00:01:18.811000         2.0
# 2             6         3.0            HAD 0 days 00:01:19.303000        20.0
# 3            16         4.0            LEC 0 days 00:01:19.327000         3.0
# 4            81         5.0            PIA 0 days 00:01:19.380000        21.0
# 5             1         6.0            NOR 0 days 00:01:19.475000         5.0
# 6            44         7.0            HAM 0 days 00:01:19.478000         4.0
# 7            30         8.0            LAW 0 days 00:01:19.994000        13.0
# 8            41         9.0            LIN 0 days 00:01:21.247000         8.0
# 9             5        10.0            BOR                    NaT         9.0
# 10           27        11.0            HUL                    NaT        22.0
# 11           87        12.0            BEA                    NaT         7.0
# 12           31        13.0            OCO                    NaT        11.0
# 13           10        14.0            GAS                    NaT        10.0
# 14           23        15.0            ALB                    NaT        12.0
# 15           43        16.0            COL                    NaT        14.0
# 16           14        17.0            ALO                    NaT        18.0
# 17           11        18.0            PER                    NaT        16.0
# 18           77        19.0            BOT                    NaT        19.0
# 19           18         NaN            STR                    NaT        17.0
# 20            3         NaN            VER                    NaT         6.0
# 21           55         NaN            SAI                    NaT        15.0
#
#    Abbreviation_y
# 0             RUS
# 1             ANT
# 2             HAD
# 3             LEC
# 4             PIA
# 5             NOR
# 6             HAM
# 7             LAW
# 8             LIN
# 9             BOR
# 10            HUL
# 11            BEA
# 12            OCO
# 13            GAS
# 14            ALB
# 15            COL
# 16            ALO
# 17            PER
# 18            BOT
# 19            STR
# 20            VER
# 21            SAI

# %%
merged['Winner'] = merged['Position_y'] == 1
merged['Winner'] = merged['Winner'].astype(int)

print(merged)
# Out:
#    DriverNumber  Position_x Abbreviation_x                     Q3  Position_y  \
# 0            63         1.0            RUS 0 days 00:01:18.518000         1.0
# 1            12         2.0            ANT 0 days 00:01:18.811000         2.0
# 2             6         3.0            HAD 0 days 00:01:19.303000        20.0
# 3            16         4.0            LEC 0 days 00:01:19.327000         3.0
# 4            81         5.0            PIA 0 days 00:01:19.380000        21.0
# 5             1         6.0            NOR 0 days 00:01:19.475000         5.0
# 6            44         7.0            HAM 0 days 00:01:19.478000         4.0
# 7            30         8.0            LAW 0 days 00:01:19.994000        13.0
# 8            41         9.0            LIN 0 days 00:01:21.247000         8.0
# 9             5        10.0            BOR                    NaT         9.0
# 10           27        11.0            HUL                    NaT        22.0
# 11           87        12.0            BEA                    NaT         7.0
# 12           31        13.0            OCO                    NaT        11.0
# 13           10        14.0            GAS                    NaT        10.0
# 14           23        15.0            ALB                    NaT        12.0
# 15           43        16.0            COL                    NaT        14.0
# 16           14        17.0            ALO                    NaT        18.0
# 17           11        18.0            PER                    NaT        16.0
# 18           77        19.0            BOT                    NaT        19.0
# 19           18         NaN            STR                    NaT        17.0
# 20            3         NaN            VER                    NaT         6.0
# 21           55         NaN            SAI                    NaT        15.0
#
#    Abbreviation_y  Winner
# 0             RUS       1
# 1             ANT       0
# 2             HAD       0
# 3             LEC       0
# 4             PIA       0
# 5             NOR       0
# 6             HAM       0
# 7             LAW       0
# 8             LIN       0
# 9             BOR       0
# 10            HUL       0
# 11            BEA       0
# 12            OCO       0
# 13            GAS       0
# 14            ALB       0
# 15            COL       0
# 16            ALO       0
# 17            PER       0
# 18            BOT       0
# 19            STR       0
# 20            VER       0
# 21            SAI       0

# %%
feature = merged['Position_x']
label = merged['Winner']

X = pd.DataFrame(feature)
y = pd.DataFrame(label)

print(X.shape)
print(y.shape)
# Out:
# (22, 1)
# (22, 1)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X,y)
# Out:
# /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages/sklearn/base.py:1336: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
model.predict_proba([[1]])
# Out:
# /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([[0.31, 0.69]])

# %%
model.predict_proba([[2]])
# Out:
# /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([[0.72, 0.28]])

# %%
model.predict_proba([[3]])
# Out:
# /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([[0.95, 0.05]])

# %%
model.predict_proba([[4]])
# Out:
# /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([[0.99, 0.01]])

# %%
predictions = []

for i in range(1,10):
    predictions.append(model.predict_proba([[i]])[0][1])

print(predictions)
# Out:
# [np.float64(0.69), np.float64(0.28), np.float64(0.05), np.float64(0.01), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /opt/homebrew/Cellar/jupyterlab/4.5.4/libexec/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
print(predictions)
# Out:
# [np.float64(0.69), np.float64(0.28), np.float64(0.05), np.float64(0.01), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]

# %%
drivers = ['RUS', 'ANT', 'HAD', 'LEC', 'PIA', 'NOR', 'HAM', 'LAW', 'LIN']

plt.bar(drivers, predictions)
plt.show()

# %%
# SOO, above was the too simple model yet correct model created. Now let's test this model for the Chinese GP'26!
